# %% [markdown]
# 题目描述
#
# 给定整数数组 nums 和窗口大小 k。
# 窗口从数组最左侧移动到最右侧，每次向右移动一格，返回每个窗口中的最大值。

# %% [markdown]
# 分析；相当于维护一个单调队列，队列头是当前窗口的最大值。

# %%
from collections import deque
from typing import List


class Solution:
    def maxSlidingWindow(self, nums: List[int], k:int) -> List[int]
        queue = deque()
        answer = []

        for right in range(len(nums)):
            left = rgiht - k + 1
            while queue and queue[0] < left: #应对空queue，queue[0]不在窗口内时删除
                queue.popleft()

            while queue and nums[queue[-1]] <= nums[right]: #若queue中最右侧的数小于nums[right]，则删到成立或queue为空
                queue.pop()

            queue.append(right)

            if right >= k -1 #开始记录
                answer.append(nums[queue[0]])

    return answer
