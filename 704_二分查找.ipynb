# %% [markdown]
# 题目：给你一个按照从小到大排列的整数数组 nums，以及一个目标值 target。
#
# 在数组中寻找 target：
#
# 找到了，返回它的下标；
# 没找到，返回 -1。

# %% [markdown]
# 分析：对范围切半，比较后，更新搜索范围

# %%
class Solutuon:
    def search(self, nums:List[int], target:int) -> int:
        left = 0
        right = len(nums) - 1

        while left <= right:
            mid = (right - left) // 2 #只保留整数部分

            if mid == target:
                return mid
            
            elif num[mid] < target:
                left = mid +1

            else:
                right = mid -1

        return -1

# %% [markdown]
# 拓展：若nums中的元素是float类型，如何处理？
# 分析：
